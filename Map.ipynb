# %% [markdown]
# <a href="https://colab.research.google.com/github/chhoummalis168-dev/ADS_2/blob/main/Map.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from typing import List,Tuple

#create a new Map
my_map = dict()

#1.Basic Operations
print("=== BASI OPERATIONS ===")

#Adding key-value pairs
my_map["name"] ="Jonn"
my_map["age"] =30
my_map["City"] ="New York"
my_map["Occupation"] ="Software Engineer"

print(f"Initial Map: {my_map}")
print(f"Size of Map: {len(my_map)}")

#Accessing values
print(f"Name: {my_map['name']}")
print(f"Age: {my_map['age']}")

#Updating value
my_map["age"] = 31
print(f"Updated Age: {my_map['age']}")

#Checking existence
print(f"Has 'City':{'City' in my_map}")
print(f"Has 'Country': {'country' in my_map}")
# Out:
# === BASI OPERATIONS ===
# Initial Map: {'name': 'Jonn', 'age': 30, 'City': 'New York', 'Occupation': 'Software Engineer'}
# Size of Map: 4
# Name: Jonn
# Age: 30
# Updated Age: 31
# Has 'City':True
# Has 'Country': False
